# %% [markdown]
# <a href="https://colab.research.google.com/github/beemaS1/DataScience/blob/main/pattern.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for i in range(6):
  print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
for i in range(5):
  print("* * * * *")
# Out:
# * * * * *
# * * * * *
# * * * * *
# * * * * *
# * * * * *

# %%
for i in range(1,6):
  print("*" * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(5,0,-1):
  print("*" * i)
# Out:
# *****
# ****
# ***
# **
# *
